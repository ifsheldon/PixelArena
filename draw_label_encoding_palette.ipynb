# %% [markdown]
# This draws the label encoding palette.

# %%
from pixel_arena.plot import plot_label_palette

# %%
from pixel_arena.dataset_utils.celeb_a_mask_hq import LABELS, LABEL_COLORS

plot_label_palette(LABELS, LABEL_COLORS, columns=4)

# %%
from pixel_arena.dataset_utils.coco import LABELS, LABEL_COLORS

plot_label_palette(LABELS, LABEL_COLORS, columns=4, row_limit_per_image=5)
